# %% [markdown]
# # Module 1 - Introduction to Pandas
# ## Pandas Part 1

# %% [markdown]
# ### Introduction
#
# ![austin](http://www.austintexas.gov/sites/default/files/aac_logo.jpg)
# You have decided that you want to start your own animal shelter, but you want to get an idea of what that will entail and get more information about planning. You have found out that Austin has one of the largest no-kill animal shelters in the country, and they keep meticulous track of animals that have been taken in and released. However, it is a large file, the online visualization tools provided are terrible, the data is sorted as strings, and the file holds an overwhelming amount  of information. Is there an easy way to look at this data? Can we do this with base Python? Is there a better way?
#
#
# #### _Our goals today are to be able to_: <br/>
#
# - Import/read data using Pandas
# - Identify Pandas objects and manipulate Pandas objects by index and columns
# - Filter data using Pandas
#
# #### _Big questions for this lesson_: <br/>
# - Why use Pandas?
#
#  (a) Provides methods able analyze data stored in the format Data Scientist most often encounter (.csv, .tsv, or .xlsx).
#
#  (b) Makes it very convenient to load, process, and analyze in the aforementioned formats.
#
#  (c) Along with python visualization packages allows for the visual analysis of tabular data.
#
#
# - When do we want to use NumPy versus Pandas?
# - What are the [advantages of using Pandas?](https://stackabuse.com/beginners-tutorial-on-the-pandas-python-library/)
# - What are the [disadvantages of using Pandas?](https://wesmckinney.com/blog/apache-arrow-pandas-internals/)
# - DataFrames are great for representing real data: rows correspond to instances (examples, observations, etc.), and columns correspond to features of these instances.

# %% [markdown]
# ### Activation:
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*9IU5fBzJisilYjRAi-f55Q.png" width=600>
#
#
#
#
# - The data manipulation capabilities of Pandas are built on top of the numpy library.
# - Pandas dataframe object represents a spreadsheet with cell values, column names, and row index labels.

# %% [markdown]
# ### 1. Importing and reading data with Pandas!
#
# #### Let's use pandas to read some csv files so we can interact with them.

# %%
# First, let's check which directory we are in so the files we expect to see are there.
# !pwd
# !ls -la data
# Out:
# /Users/enkeboll/code/fis/dc-ds-010620/module-1/day-5-pandas-1
# total 16
# drwxr-xr-x  4 enkeboll  staff  128 Dec 30 11:09 .
# drwxr-xr-x  6 enkeboll  staff  192 Jan 10 11:22 ..
# -rw-r--r--  1 enkeboll  staff   62 Dec 30 11:09 example1.csv
# -rw-r--r--  1 enkeboll  staff  238 Dec 30 11:09 made_up_jobs.csv

# %%
# !head data/example1.csv
# Out:
# Title1,Title2,Title3
# one,two,three
# example1,example2,example3

# %%
import pandas as pd

example_csv = pd.read_csv('data/example1.csv', sep='\t')

# %%
my_string = "Hello!\nMy name is \t\t ANDY!"

# %%
my_string
# Out:
# 'Hello!\nMy name is \t\t ANDY!'

# %%
print(my_string)
# Out:
# Hello!
# My name is 		 ANDY!

# %%
example_csv
# Out:
#      Title1    Title2    Title3
# 0       one       two     three
# 1  example1  example2  example3

# %%
pd.read_

# %% [markdown]
# There is also `read_excel`, `read_html`, and many other pandas `read_` functions.
# http://pandas.pydata.org/pandas-docs/stable/user_guide/io.html

# %%
example_csv.describe()
# Out:
#        Title1 Title2    Title3
# count       2      2         2
# unique      2      2         2
# top       one    two  example3
# freq        1      1         1

# %%
example_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
# Title1    2 non-null object
# Title2    2 non-null object
# Title3    2 non-null object
# dtypes: object(3)
# memory usage: 128.0+ bytes

# %%
None
import numpy as np

np.NaN
# Out:
# nan

# %% [markdown]
# Try loading in the example file in the `data` directory called `made_up_jobs.csv` using pandas.

# %%
# !head data/made_up_jobs.csv
# Out:
# ID,Name,Job,Years Employed
# 0,Bob Bobberty,Underwater Basket Weaver,13
# 1,Susan Smells,Salad Spinner,5
# 2,Alex Lastname,Productivity Manager,2
# 3,Rudy P.,Being cool,55
# 4,Rudy G.,Being compared to Rudy P,50
# 5,Sir Wellington,Cheese Stacker, 10

# %%
# read in your csv here!
muj = pd.read_csv('data/made_up_jobs.csv', index_col='ID')

# remember that it's nice to be able to look at your data, so let's do that here, too.
muj.head()
# Out:
#              Name                       Job  Years Employed
# ID
# 0    Bob Bobberty  Underwater Basket Weaver              13
# 1    Susan Smells             Salad Spinner               5
# 2   Alex Lastname      Productivity Manager               2
# 3         Rudy P.                Being cool              55
# 4         Rudy G.  Being compared to Rudy P              50

# %%
muj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
# ID                6 non-null int64
# Name              6 non-null object
# Job               6 non-null object
# Years Employed    6 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 272.0+ bytes

# %% [markdown]
# You can also load in data directly from the internet with its url.

# %%
shelter_data = pd.read_csv('https://data.austintexas.gov/api/views/9t4d-g238/rows.csv?accessType=DOWNLOAD')
# this link is copied directly from the download option for CSV

shelter_data.head()
# Out:
#   Animal ID        Name                DateTime               MonthYear  \
# 0   A720371       Moose  02/13/2016 05:59:00 PM  02/13/2016 05:59:00 PM
# 1   A674754         NaN  03/18/2014 11:47:00 AM  03/18/2014 11:47:00 AM
# 2   A689724  *Donatello  10/18/2014 06:52:00 PM  10/18/2014 06:52:00 PM
# 3   A680969       *Zeus  08/05/2014 04:59:00 PM  08/05/2014 04:59:00 PM
# 4   A684617         NaN  07/27/2014 09:00:00 AM  07/27/2014 09:00:00 AM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    10/08/2015     Adoption             NaN         Dog    Neutered Male
# 1    03/12/2014     Transfer         Partner         Cat      Intact Male
# 2    08/01/2014     Adoption             NaN         Cat    Neutered Male
# 3    06/03/2014     Adoption             NaN         Cat    Neutered Male
# 4    07/26/2012     Transfer            SCRP         Cat    Intact Female
#
#   Age upon Outcome                               Breed               Color
# 0         4 months  Anatol Shepherd/Labrador Retriever                Buff
# 1           6 days              Domestic Shorthair Mix        Orange Tabby
# 2         2 months              Domestic Shorthair Mix               Black
# 3         2 months              Domestic Shorthair Mix  White/Orange Tabby
# 4          2 years              Domestic Shorthair Mix               Black

# %%
shelter_data.head(2)
# Out:
#   Animal ID   Name                DateTime               MonthYear  \
# 0   A720371  Moose  02/13/2016 05:59:00 PM  02/13/2016 05:59:00 PM
# 1   A674754    NaN  03/18/2014 11:47:00 AM  03/18/2014 11:47:00 AM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    10/08/2015     Adoption             NaN         Dog    Neutered Male
# 1    03/12/2014     Transfer         Partner         Cat      Intact Male
#
#   Age upon Outcome                               Breed         Color
# 0         4 months  Anatol Shepherd/Labrador Retriever          Buff
# 1           6 days              Domestic Shorthair Mix  Orange Tabby

# %% [markdown]
# Now that we can read in data, let's get more comfortable with our Pandas data structures.

# %%
type(shelter_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Now that data is read let's look at it's shape
print(shelter_data.shape)
# Out:
# (113950, 12)

# %%
print(shelter_data.size)
# Out:
# 1367400

# %%
# What are the names of the columns
print(shelter_data.columns)
# Out:
# Index(['Animal ID', 'Name', 'DateTime', 'MonthYear', 'Date of Birth',
#        'Outcome Type', 'Outcome Subtype', 'Animal Type', 'Sex upon Outcome',
#        'Age upon Outcome', 'Breed', 'Color'],
#       dtype='object')

# %%
# What are the different data types present in our data
print(shelter_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113950 entries, 0 to 113949
# Data columns (total 12 columns):
# Animal ID           113950 non-null object
# Name                78118 non-null object
# DateTime            113950 non-null object
# MonthYear           113950 non-null object
# Date of Birth       113950 non-null object
# Outcome Type        113942 non-null object
# Outcome Subtype     51633 non-null object
# Animal Type         113950 non-null object
# Sex upon Outcome    113946 non-null object
# Age upon Outcome    113920 non-null object
# Breed               113950 non-null object
# Color               113950 non-null object
# dtypes: object(12)
# memory usage: 10.4+ MB
# None

# %%
# We can find the type of a particular columns in a data frame in this way.
ID_series = shelter_data['Animal ID']
type(ID_series)
# Out:
# pandas.core.series.Series

# %%
ID_series.dtype
# Out:
# dtype('O')

# %%
shelter_data['RealDateTime'] = pd.to_datetime(shelter_data['DateTime'])

# %%
shelter_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113950 entries, 0 to 113949
# Data columns (total 13 columns):
# Animal ID           113950 non-null object
# Name                78118 non-null object
# DateTime            113950 non-null object
# MonthYear           113950 non-null object
# Date of Birth       113950 non-null object
# Outcome Type        113942 non-null object
# Outcome Subtype     51633 non-null object
# Animal Type         113950 non-null object
# Sex upon Outcome    113946 non-null object
# Age upon Outcome    113920 non-null object
# Breed               113950 non-null object
# Color               113950 non-null object
# RealDateTime        113950 non-null datetime64[ns]
# dtypes: datetime64[ns](1), object(12)
# memory usage: 11.3+ MB

# %%
shelter_data.sort_values('RealDateTime')
# Out:
#       Animal ID          Name                DateTime               MonthYear  \
# 39234   A659834       *Dudley  10/01/2013 09:31:00 AM  10/01/2013 09:31:00 AM
# 32288   A664235           NaN  10/01/2013 10:39:00 AM  10/01/2013 10:39:00 AM
# 65689   A664237           NaN  10/01/2013 10:44:00 AM  10/01/2013 10:44:00 AM
# 58062   A664236           NaN  10/01/2013 10:44:00 AM  10/01/2013 10:44:00 AM
# 7866    A664223          Moby  10/01/2013 11:03:00 AM  10/01/2013 11:03:00 AM
# 20699   A663646           NaN  10/01/2013 11:12:00 AM  10/01/2013 11:12:00 AM
# 69129   A663888           NaN  10/01/2013 11:13:00 AM  10/01/2013 11:13:00 AM
# 18433   A663572       *Starla  10/01/2013 11:42:00 AM  10/01/2013 11:42:00 AM
# 19385   A663833     Baby Girl  10/01/2013 11:50:00 AM  10/01/2013 11:50:00 AM
# 6037    A661795        Blakie  10/01/2013 11:53:00 AM  10/01/2013 11:53:00 AM
# 33890   A656894          Jake  10/01/2013 11:53:00 AM  10/01/2013 11:53:00 AM
# 33956   A663342          Deco  10/01/2013 12:05:00 PM  10/01/2013 12:05:00 PM
# 62039   A664225           Lou  10/01/2013 12:13:00 PM  10/01/2013 12:13:00 PM
# 27246   A663546         *Gage  10/01/2013 12:24:00 PM  10/01/2013 12:24:00 PM
# 56221   A648744        Claire  10/01/2013 12:27:00 PM  10/01/2013 12:27:00 PM
# 15294   A664258        Sylvio  10/01/2013 12:27:00 PM  10/01/2013 12:27:00 PM
# 14288   A613553         Beast  10/01/2013 12:32:00 PM  10/01/2013 12:32:00 PM
# 17628   A664219           NaN  10/01/2013 12:34:00 PM  10/01/2013 12:34:00 PM
# 48649   A663495       Pikachu  10/01/2013 12:45:00 PM  10/01/2013 12:45:00 PM
# 29510   A664271           NaN  10/01/2013 12:57:00 PM  10/01/2013 12:57:00 PM
# 69678   A664263           NaN  10/01/2013 12:58:00 PM  10/01/2013 12:58:00 PM
# 22724   A664262           NaN  10/01/2013 12:59:00 PM  10/01/2013 12:59:00 PM
# 46954   A664261           NaN  10/01/2013 01:00:00 PM  10/01/2013 01:00:00 PM
# 67816   A664260           NaN  10/01/2013 01:00:00 PM  10/01/2013 01:00:00 PM
# 61106   A663938           NaN  10/01/2013 01:16:00 PM  10/01/2013 01:16:00 PM
# 14758   A664171        Knight  10/01/2013 01:59:00 PM  10/01/2013 01:59:00 PM
date of Birth     Outcome Type Outcome Subtype Animal Type  \
# 39234    07/23/2013         Adoption          Foster         Dog
# 32288    09/24/2013         Transfer         Partner         Cat
# 65689    09/24/2013         Transfer         Partner         Cat
# 58062    09/24/2013         Transfer         Partner         Cat
# 7866     09/30/2009  Return to Owner             NaN         Dog
# 20699    09/22/2010         Transfer         Partner         Dog
# 69129    09/25/2011         Transfer         Partner         Dog
# 18433    09/21/2010         Adoption             NaN         Dog
# 19385    09/24/2004  Return to Owner             NaN         Dog
# 6037     03/25/2013         Adoption             NaN         Cat
# 33890    04/22/2013         Adoption             NaN         Cat
# 33956    09/17/2012       Euthanasia        Behavior         Dog
# 62039    09/30/2010  Return to Owner             NaN         Dog
# 27246    09/20/2011       Euthanasia      Aggressive         Dog
# 56221    03/04/2012  Return to Owner             NaN         Dog
# 15294    10/01/2006  Return to Owner             NaN         Dog
# 14288    05/06/2010  Return to Owner             NaN         Dog
# 17628    08/08/2013             Died       In Kennel         Cat
# 48649    05/19/2013  Return to Owner             NaN         Cat
# 29510    09/24/2013         Transfer         Partner         Cat
# 69678    09/22/2013         Transfer         Partner         Cat
# 22724    09/22/2013         Transfer         Partner         Cat
# 46954    09/10/2013         Transfer         Partner         Cat
# 67816    09/10/2013         Transfer         Partner         Cat
# 61106    09/27/2003       Euthanasia       Suffering         Dog
# 14758    12/30/2012  Return to Owner             NaN         Dog
# 75920    09/27/1999         Transfer         Partner         Dog
# 14272    09/14/2011         Transfer         Partner         Dog
# 45191    09/26/1999         Transfer         Partner         Dog
# 1250     09/25/2010       Euthanasia         Medical         Dog
# ...             ...              ...             ...         ...
# 54502    12/19/2017         Transfer         Partner         Dog
# 54545    01/04/2006         Transfer         Partner         Dog
# 54541    09/20/2010         Adoption             NaN         Dog
# 54544    04/04/2011       Euthanasia       Suffering         Cat
# 54547    12/07/2013         Adoption             NaN         Dog
# 54548    12/23/2017  Return to Owner             NaN         Dog
# 54559    01/06/2018         Transfer         Partner         Dog
# 54562    12/29/2017         Transfer         Partner         Dog
# 54568    01/09/2013       Euthanasia       Suffering         Dog
# 54569    03/26/2019         Adoption             NaN         Dog
# 54567    01/08/2018         Transfer         Partner         Cat
# 54563    07/02/2019         Adoption             NaN         Cat
# 54573    12/29/2018         Adoption             NaN         Dog
# 54585    11/13/2019         Adoption          Foster         Dog
# 54586    12/30/2018         Adoption             NaN         Cat
# 54583    10/29/2019         Adoption             NaN         Dog
# 54587    09/13/2019         Adoption             NaN         Cat
# 54575    12/31/2015         Adoption             NaN         Dog
# 54571    10/15/2019         Adoption             NaN         Dog
# 54576    11/18/2019         Adoption          Foster         Dog
# 54580    09/20/2019         Adoption             NaN         Cat
# 54579    09/20/2019         Adoption             NaN         Cat
# 54622    07/09/2018  Return to Owner             NaN         Cat
# 54619    08/05/2019         Adoption             NaN         Cat
# 54623    09/01/2017         Adoption             NaN         Dog
# 54616    10/19/2019         Adoption             NaN         Dog
# 54622                White 2020-01-09 17:22:00
# 54619          Brown Tabby 2020-01-09 17:33:00
# 54623                White 2020-01-09 17:41:00
# 54616           Gray/White 2020-01-09 17:52:00
# 54625                 Blue 2020-01-09 18:05:00
# 54632    Brown Tabby/White 2020-01-09 19:11:00
# 54634                 Gray 2020-01-10 08:32:00
# 54639          White/Black 2020-01-10 09:54:00
#
# [113950 rows x 13 columns]

# %%
shelter_data['Outcome Type'].value_counts()
# Out:
# Adoption           50093
# Transfer           34014
# Return to Owner    20067
# Euthanasia          7626
# Died                1047
# Rto-Adopt            556
# Disposal             452
# Missing               67
# Relocate              20
# Name: Outcome Type, dtype: int64

# %%
columns_to_check = [x for x in shelter_data.columns if x != 'Animal ID']

# %%
columns_to_check
# Out:
# ['Name',
#  'DateTime',
#  'MonthYear',
#  'Date of Birth',
#  'Outcome Type',
#  'Outcome Subtype',
#  'Animal Type',
#  'Sex upon Outcome',
#  'Age upon Outcome',
#  'Breed',
#  'Color',
#  'RealDateTime']

# %%
shelter_data_dedup = shelter_data.drop_duplicates(subset=columns_to_check).sort_values('RealDateTime')

# %%
shelter_data.shape
# Out:
# (113950, 13)

# %%
shelter_data_dedup.shape
# Out:
# (112010, 13)

# %% [markdown]
# ### 2. Utilizing and identifying Pandas objects
#
# - What is a DataFrame object and what is a Series object?
# - How are they different from Python lists?
#
# To start, let's start with this list of fruits.

# %%
fruits = ['Apple', 'Orange', 'Watermelon', 'Lemon', 'Mango']

print(fruits)
# Out:
# ['Apple', 'Orange', 'Watermelon', 'Lemon', 'Mango']

# %% [markdown]
# Using our list of fruits, we can create a pandas object called a 'series' which is much like an array or a vector, or a column from a spreadsheet.

# %%
fruits_series = pd.Series(fruits)

print(fruits_series)
type(fruits_series)
# Out:
# 0         Apple
# 1        Orange
# 2    Watermelon
# 3         Lemon
# 4         Mango
# dtype: object
# pandas.core.series.Series

# %% [markdown]
# One difference between python **list objects** and pandas **series objects** is the fact that you can define the index manually for a **series objects**.

# %%
ind = ['a', 'b', 'c', 'd', 'e']

fruits_series = pd.Series(fruits, index=ind)

print(fruits_series)
# Out:
# a         Apple
# b        Orange
# c    Watermelon
# d         Lemon
# e         Mango
# dtype: object

# %% [markdown]
# With a partner, create your own custom series from a list of items.

# %%
my_list = ['Chalupa', 'Crunchwrap Supreme', 'Burrito Supreme']

# create custom indices for your series
ind = ['item1', 'item2', 'item3']

# create the series using your list objects
# You can use either a for loop or also pd.Series
my_series = pd.Series(my_list, index=ind)

# print your objects
print(my_series)
type(my_series)
# Out:
# item1               Chalupa
# item2    Crunchwrap Supreme
# item3       Burrito Supreme
# dtype: object
# pandas.core.series.Series

# %% [markdown]
# We can do a simliar thing with Python dictionaries. This time, however, we will create a DataFrame object from a python dictionary.

# %%
# Dictionary with list objects in values
student_dict = {
    'name': ['Samantha', 'Alex', 'Dante'],
    'age': ['35', '17', '26'],
    'city': ['Houston', 'Seattle', 'New York']
}

students_df = pd.DataFrame(student_dict)

students_df.head()
# Out:
#        name age      city
# 0  Samantha  35   Houston
# 1      Alex  17   Seattle
# 2     Dante  26  New York

# %%
# List with dictionary objects in values
student_list = [
    {'name': 'Samantha', 'age': '35', 'city': 'Houston'},
    {'name': 'Alex', 'age': '17', 'city': 'Seattle'},
    {'name': 'Dante', 'age': '26', 'city': 'New York'}
]

students_df = pd.DataFrame(student_list, columns=['name', 'age', 'city'])

students_df.head()
# Out:
#        name age      city
# 0  Samantha  35   Houston
# 1      Alex  17   Seattle
# 2     Dante  26  New York

# %%
#to find data types of columns
students_df.dtypes
# Out:
# age     object
# city    object
# name    object
# dtype: object

# %% [markdown]
# Let's change the data type of ages to int.

# %%
students_df.age.astype(int)
# Out:
# 0    35
# 1    17
# 2    26
# Name: age, dtype: int64

# %%
students_df.age
# Out:
# 0    35
# 1    17
# 2    26
# Name: age, dtype: object

# %%
# We can also change a columns type but the change has to make sense.
# students_df.age = students_df.age.astype(int)

# Uncomment line below and observe what happens when trying to convert student's name to int or float
students_df.name = students_df.age.astype(float)

# How about what happens converting numeric to string
# students_df.age = students_df.age.astype(str)

students_df.dtypes
# Out:
# name    float64
# age      object
# city     object
# dtype: object

# %% [markdown]
# We can also use a custom index for these items. For example, we might want them to be the individual student ID numbers.

# %%
school_ids = ['1111', '1145', '0096']

# Notice here we use pd.DataFrame not pd.Series as we did for a pandas series.
students_df = pd.DataFrame(student_dict, index=school_ids)

students_df.head()
# Out:
#           name age      city
# 1111  Samantha  35   Houston
# 1145      Alex  17   Seattle
# 0096     Dante  26  New York

# %% [markdown]
# Using Pandas, we can also rename column names.

# %%
students_df.columns = [x.upper() for x in students_df.columns]
students_df.head()
# Out:
#           NAME AGE      HOME
# 1111  Samantha  35   Houston
# 1145      Alex  17   Seattle
# 0096     Dante  26  New York

# %% [markdown]
# Or, we can also change the column names using the rename function.

# %%
students_df.rename(columns={"AGE": "YEARS"})
# Out:
#           NAME YEARS      HOME
# 1111  Samantha    35   Houston
# 1145      Alex    17   Seattle
# 0096     Dante    26  New York

# %%
# Notice what happens when we print students_df

students_df
# Out:
#           NAME AGE      HOME
# 1111  Samantha  35   Houston
# 1145      Alex  17   Seattle
# 0096     Dante  26  New York

# %%
# If you want the file to save over itself, use the option `inplace = True`.
students_df.rename(columns={'AGE': 'YEARS'}, inplace=True)
students_df.head()
# Out:
#           NAME YEARS      HOME
# 1111  Samantha    35   Houston
# 1145      Alex    17   Seattle
# 0096     Dante    26  New York

# %% [markdown]
# Similarly, there is a tool to remove rows and columns from your DataFrame

# %%
students_df.drop(columns=['YEARS', 'HOME'])
# Out:
#           NAME
# 1111  Samantha
# 1145      Alex
# 0096     Dante

# %%
#Notice again what happens if we print students_df 
students_df
# Out:
#           NAME YEARS      HOME
# 1111  Samantha    35   Houston
# 1145      Alex    17   Seattle
# 0096     Dante    26  New York

# %%
students_df = students_df.drop(columns=['YEARS', 'HOME'])
students_df
# Out:
#           NAME
# 1111  Samantha
# 1145      Alex
# 0096     Dante

# %% [markdown]
# If you want the file to save over itself, use the option `inplace = True`.
#
# Every function has options. Let's read more about `drop` [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)
