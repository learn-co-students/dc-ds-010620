# %% [markdown]
# ### Apply to Animal Shelter Data
#
# Use an `apply` to change the dates from strings to datetime objects. Similarly, use an apply to change the ages of the animals from strings to floats.

# %%
import pandas as pd
animal_outcomes = pd.read_csv('https://data.austintexas.gov/api/views/9t4d-g238/rows.csv?accessType=DOWNLOAD')

# %%
# Use an apply to change the dates from strings to datetime objects
animal_outcomes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114105 entries, 0 to 114104
# Data columns (total 12 columns):
# Animal ID           114105 non-null object
# Name                78240 non-null object
# DateTime            114105 non-null object
# MonthYear           114105 non-null object
# Date of Birth       114105 non-null object
# Outcome Type        114098 non-null object
# Outcome Subtype     51688 non-null object
# Animal Type         114105 non-null object
# Sex upon Outcome    114101 non-null object
# Age upon Outcome    114077 non-null object
# Breed               114105 non-null object
# Color               114105 non-null object
# dtypes: object(12)
# memory usage: 10.4+ MB

# %%
import datetime
animal_outcomes.DateTime = animal_outcomes.DateTime.apply(lambda x: datetime.datetime.strptime(x, '%m/%d/%Y %I:%M:%S %p'))

# %%
pd.to_datetime(animal_outcomes.DateTime)
# Out:
# 0        2016-02-13 17:59:00
# 1        2014-03-18 11:47:00
# 2        2014-10-18 18:52:00
# 3        2014-08-05 16:59:00
# 4        2014-07-27 09:00:00
#                  ...
# 114100   2017-10-18 13:27:00
# 114101   2018-03-01 18:28:00
# 114102   2018-06-23 11:59:00
# 114103   2018-05-21 12:59:00
# 114104   2018-03-12 13:27:00
# Name: DateTime, Length: 114105, dtype: datetime64[ns]

# %%
# ages of the animals from strings to floats.
animal_outcomes['Age upon Outcome'].head()
# Out:
# 0    4 months
# 1      6 days
# 2    2 months
# 3    2 months
# 4     2 years
# Name: Age upon Outcome, dtype: object

# %%
animal_outcomes['Age upon Outcome'].value_counts()
# Out:
# 1 year       20529
# 2 years      16881
# 2 months     13769
# 3 years       6949
# 3 months      5350
# 1 month       5053
# 4 years       4109
# 5 years       3804
# 4 months      3641
# 5 months      2809
# 6 months      2748
# 6 years       2539
# 8 years       2178
# 7 years       2165
# 3 weeks       2017
# 2 weeks       1912
# 8 months      1813
# 10 years      1731
# 4 weeks       1718
# 10 months     1645
# 7 months      1462
# 9 years       1189
# 9 months      1187
# 12 years       851
# 1 weeks        768
# 11 months      708
# 11 years       674
# 1 week         626
# 13 years       542
# 14 years       361
# 2 days         330
# 3 days         321
# 15 years       302
# 1 day          240
# 6 days         228
# 4 days         201
# 0 years        164
# 5 days         145
# 16 years       132
# 5 weeks        109
# 17 years        77
# 18 years        48
# 19 years        23
# 20 years        17
# -1 years         4
# 22 years         4
# 24 years         1
# -3 years         1
# 25 years         1
# 21 years         1
# Name: Age upon Outcome, dtype: int64

# %%
animal_outcomes['Age upon Outcome'].isna().sum()
# Out:
# 28

# %%
x = 5
y = 5

x == y
# Out:
# True

# %%
x is y
# Out:
# True

# %%
id(5)
# Out:
# 4543827856

# %%
x=6
id(x)
# Out:
# 4543827888

# %%
id(y)
# Out:
# 4543827856

# %%
x = np.NaN
y = np.NaN

# %%
x is y
# Out:
# True

# %%
id(x) == id(y)
# Out:
# True

# %%
x == y
# Out:
# False

# %%
header = 'Andy Enkeboll'
print(header)
print('='*len(header))
# Out:
# Andy Enkeboll
# =============

# %%
import numpy as np
def age_string_to_days_old(age):
    if age is np.NaN:
        return age
    qty, unit = age.split(' ')
    qty = int(qty)
    if 'day' in unit:
        return qty
    elif 'week' in unit:
        return qty * 7
    elif 'month' in unit:
        return qty * 30
    elif 'year' in unit:
        return qty * 365
    
    return np.NaN

animal_outcomes['age'] = animal_outcomes['Age upon Outcome'].apply(age_string_to_days_old)

# %% [markdown]
# ## 3. Methods for Re-Organizing DataFrames
# #### `.groupby()`

# %% [markdown]
# Those of you familiar with SQL have probably used the GROUP BY command. Pandas has this, too.
#
# The `.groupby()` method is especially useful for aggregate functions applied to the data grouped in particular ways.

# %%
uci = pd.read_csv('data/heart.csv')

# %%
uci.sex.value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
uci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
uci.groupby('age')

# %% [markdown]
# #### `.groups` and `.get_group()`

# %%
uci.groupby('age').groups
# Out:
# {29: Int64Index([72], dtype='int64'),
#  34: Int64Index([58, 125], dtype='int64'),
#  35: Int64Index([65, 157, 227, 239], dtype='int64'),
#  37: Int64Index([1, 115], dtype='int64'),
#  38: Int64Index([163, 164, 259], dtype='int64'),
#  39: Int64Index([44, 124, 154, 212], dtype='int64'),
#  40: Int64Index([24, 175, 283], dtype='int64'),
#  41: Int64Index([2, 30, 63, 80, 116, 122, 133, 134, 162, 189], dtype='int64'),
#  42: Int64Index([22, 84, 100, 103, 132, 142, 149, 280], dtype='int64'),
#  43: Int64Index([18, 74, 98, 113, 141, 178, 215, 251], dtype='int64'),
#  44: Int64Index([7, 21, 32, 46, 53, 68, 146, 148, 185, 200, 294], dtype='int64'),
#  45: Int64Index([42, 57, 67, 81, 94, 107, 255, 299], dtype='int64'),
#  46: Int64Index([35, 87, 118, 119, 196, 270, 285], dtype='int64'),
#  47: Int64Index([47, 126, 156, 230, 274], dtype='int64'),
#  48: Int64Index([11, 41, 56, 90, 171, 219, 245], dtype='int64'),
#  49: Int64Index([12, 131, 135, 208, 267], dtype='int64'),
#  50: Int64Index([15, 104, 108, 109, 184, 188, 257], dtype='int64'),
#  51: Int64Index([27, 34, 40, 50, 66, 71, 73, 76, 140, 190, 235, 250], dtype='int64'),
#  52: Int64Index([8, 45, 55, 62, 78, 83, 92, 97, 128, 205, 261, 275, 281], dtype='int64'),
#  53: Int64Index([29, 43, 48, 49, 95, 99, 169, 262], dtype='int64'),
#  54: Int64Index([10, 33, 36, 37, 61, 70, 88, 93, 123, 130, 187, 192, 224, 248, 264,
#              268],
#             dtype='int64'),
#  55: Int64Index([75, 114, 161, 180, 221, 232, 266, 289], dtype='int64'),
#  56: Int64Index([3, 6, 117, 159, 160, 170, 214, 223, 244, 246, 269], dtype='int64'),
#  57: Int64Index([4, 5, 9, 59, 91, 111, 138, 179, 210, 231, 243, 277, 287, 288, 298,
#              301, 302],
#             dtype='int64'),
#  58: Int64Index([ 14,  16,  64,  79,  89, 155, 158, 172, 173, 183, 191, 202, 236,
#              256, 273, 276, 278, 291, 292],
#             dtype='int64'),
#  59: Int64Index([20, 26, 77, 101, 121, 195, 206, 209, 228, 241, 254, 282, 286, 297], dtype='int64'),
#  60: Int64Index([82, 136, 147, 174, 176, 186, 193, 194, 201, 207, 237], dtype='int64'),
#  61: Int64Index([23, 182, 211, 213, 271, 279, 284, 290], dtype='int64'),
#  62: Int64Index([52, 69, 96, 137, 167, 198, 204, 216, 226, 252, 258], dtype='int64'),
#  63: Int64Index([0, 54, 102, 168, 217, 220, 263, 295, 296], dtype='int64'),
#  64: Int64Index([13, 110, 112, 120, 139, 152, 177, 229, 233, 242], dtype='int64'),
#  65: Int64Index([28, 31, 38, 39, 181, 199, 218, 222], dtype='int64'),
#  66: Int64Index([17, 51, 150, 153, 247, 260, 265], dtype='int64'),
#  67: Int64Index([85, 127, 143, 165, 166, 197, 253, 272, 293], dtype='int64'),
#  68: Int64Index([86, 105, 203, 300], dtype='int64'),
#  69: Int64Index([19, 106, 249], dtype='int64'),
#  70: Int64Index([145, 225, 234, 240], dtype='int64'),
#  71: Int64Index([25, 60, 151], dtype='int64'),
#  74: Int64Index([129], dtype='int64'),
#  76: Int64Index([144], dtype='int64'),
#  77: Int64Index([238], dtype='int64')}

# %%
uci.groupby('age').get_group(60) # .tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 82    60    0   2       102   318    0        1      160      0      0.0
# 136   60    0   2       120   178    1        1       96      0      0.0
# 147   60    0   3       150   240    0        1      171      0      0.9
# 174   60    1   0       130   206    0        0      132      1      2.4
# 176   60    1   0       117   230    1        1      160      1      1.4
# 186   60    1   0       130   253    0        1      144      1      1.4
# 193   60    1   0       145   282    0        0      142      1      2.8
# 194   60    1   2       140   185    0        0      155      0      3.0
# 201   60    1   0       125   258    0        0      141      1      2.8
# 207   60    0   0       150   258    0        0      157      0      2.6
# 237   60    1   0       140   293    0        0      170      0      1.2
#
#      slope  ca  thal  target
# 82       2   1     2       1
# 136      2   0     2       1
# 147      2   0     2       1
# 174      1   2     3       0
# 176      2   2     3       0
# 186      2   1     3       0
# 193      1   2     3       0
# 194      1   0     2       0
# 201      1   1     3       0
# 207      1   2     3       0
# 237      1   2     3       0

# %% [markdown]
# ### Aggregating

# %%
uci.groupby('age').median()
# Out:
#      sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# age
# 29   1.0  1.0     130.0  204.0  0.0      0.0    202.0    0.0     0.00    2.0
# 34   0.5  2.0     118.0  196.0  0.0      0.5    183.0    0.0     0.35    2.0
# 35   1.0  0.0     124.0  195.0  0.0      1.0    165.0    0.5     0.70    2.0
# 37   0.5  2.0     125.0  232.5  0.0      1.0    178.5    0.0     1.75    1.0
# 38   1.0  2.0     138.0  175.0  0.0      1.0    173.0    0.0     0.00    2.0
# 39   0.5  2.0     128.0  219.5  0.0      1.0    165.5    0.0     0.00    1.5
# 40   1.0  0.0     140.0  199.0  0.0      1.0    178.0    1.0     1.40    2.0
# 41   1.0  1.0     116.0  209.0  0.0      1.0    168.0    0.0     0.00    2.0
# 42   1.0  1.5     125.0  242.0  0.0      1.0    167.5    0.0     0.30    1.5
# 43   1.0  0.0     126.0  247.0  0.0      1.0    161.5    0.0     1.35    1.0
# 44   1.0  1.0     120.0  226.0  0.0      1.0    173.0    0.0     0.00    2.0
# 45   1.0  0.5     121.5  248.0  0.0      0.0    150.0    0.0     0.10    1.0
# 46   1.0  1.0     138.0  231.0  0.0      1.0    152.0    0.0     0.80    1.0
# 47   1.0  2.0     112.0  253.0  0.0      1.0    152.0    0.0     0.00    2.0
# 48   1.0  1.0     124.0  255.0  0.0      0.0    168.0    0.0     0.20    2.0
# 49   1.0  1.0     130.0  266.0  0.0      1.0    162.0    0.0     0.60    2.0
# 50   1.0  1.0     129.0  233.0  0.0      1.0    159.0    0.0     0.90    1.0
# 51   1.0  2.0     127.5  258.5  0.0      0.5    146.0    1.0     1.20    2.0
# 52   1.0  1.0     128.0  212.0  0.0      1.0    168.0    0.0     0.10    2.0
# 53   1.0  0.0     130.0  230.0  0.0      0.0    147.5    0.0     0.20    1.5
# 54   1.0  1.0     123.0  262.0  0.0      0.0    157.0    0.0     0.45    1.5
# 55   0.5  0.0     133.5  275.5  0.0      1.0    138.5    1.0     1.30    1.0
# 56   1.0  1.0     130.0  249.0  0.0      0.0    150.0    1.0     1.30    1.0
# 57   1.0  0.0     132.0  236.0  0.0      1.0    148.0    0.0     0.40    1.0
# 58   1.0  0.0     128.0  240.0  0.0      0.0    152.0    0.0     1.00    1.0
# 59   1.0  0.5     145.0  236.5  0.0      0.5    151.0    0.0     0.65    1.0
# 60   1.0  0.0     130.0  253.0  0.0      0.0    155.0    0.0     1.40    1.0
# 61   1.0  0.0     139.0  238.5  0.0      0.5    142.5    1.0     1.45    1.0
# 62   0.0  0.0     130.0  263.0  0.0      1.0    145.0    0.0     1.40    1.0
# 63   0.0  0.0     135.0  252.0  0.0      0.0    150.0    0.0     1.80    1.0
# 64   1.0  1.0     135.0  283.0  0.0      1.0    132.5    0.5     1.20    1.0
# 65   0.5  1.0     139.0  261.5  0.0      0.0    149.5    0.0     0.80    2.0
# 66   1.0  0.0     150.0  228.0  0.0      0.0    138.0    0.0     0.40    1.0
# 67   1.0  0.0     120.0  254.0  0.0      0.0    142.0    0.0     0.90    1.0
# 68   1.0  2.0     132.0  242.5  0.5      0.5    145.5    0.0     1.55    1.0
# 69   1.0  3.0     140.0  239.0  0.0      0.0    146.0    0.0     1.80    1.0
# 70   1.0  0.5     150.5  257.0  0.0      0.5    118.5    0.5     2.50    1.0
# 71   0.0  1.0     112.0  265.0  0.0      1.0    130.0    0.0     0.40    2.0
# 74   0.0  1.0     120.0  269.0  0.0      0.0    121.0    1.0     0.20    2.0
# 76   0.0  2.0     140.0  197.0  0.0      2.0    116.0    0.0     1.10    1.0
# 77   1.0  0.0     125.0  304.0  0.0      0.0    162.0    1.0     0.00    2.0
#
#       ca  thal  target
# age
# 29   0.0   2.0     1.0
# 34   0.0   2.0     1.0
# 35   0.0   2.5     0.5
# 37   0.0   2.0     1.0
# 38   4.0   2.0     1.0
# 39   0.0   2.0     1.0
# 40   0.0   3.0     0.0
# 41   0.0   2.0     1.0
# 42   0.0   2.0     1.0
# 43   0.0   2.5     1.0
# 44   0.0   2.0     1.0
# 45   0.0   2.0     1.0
# 46   0.0   2.0     1.0
# 47   0.0   2.0     1.0
# 48   0.0   2.0     1.0
# 49   0.0   2.0     1.0
# 50   0.0   2.0     1.0
# 51   0.0   2.0     1.0
# 52   0.0   2.0     1.0
# 53   0.0   2.0     1.0
# 54   1.0   2.0     1.0
# 55   0.0   2.5     0.0
# 56   0.0   2.0     0.0
# 57   1.0   3.0     0.0
# 58   1.0   3.0     0.0
# 59   0.0   2.0     0.0
# 60   1.0   3.0     0.0
# 61   1.0   2.5     0.0
# 62   1.0   2.0     0.0
# 63   2.0   2.0     0.0
# 64   0.0   2.0     1.0
# 65   1.0   2.0     0.5
# 66   1.0   2.0     1.0
# 67   2.0   2.0     0.0
# 68   0.5   3.0     0.5
# 69   2.0   2.0     1.0
# 70   0.5   2.5     0.0
# 71   1.0   2.0     1.0
# 74   1.0   2.0     1.0
# 76   0.0   2.0     1.0
# 77   3.0   2.0     0.0

# %% [markdown]
# Exercise: Tell me the average cholesterol level for those with heart disease.

# %%
# Your code here!
uci.groupby('target').get_group(1).chol.mean()
# Out:
# 242.23030303030302

# %%
uci.loc[uci.target == 1].chol.mean()
# Out:
# 242.23030303030302

# %% [markdown]
# ### Apply to Animal Shelter Data
#
# #### Task 1
# - Use a groupby to show the average age of the different kinds of animal types.
# - What about by animal types **and** gender?

# %%
animal_outcomes.groupby('Animal Type').mean()
# Out:
#                     age
# Animal Type
# Bird         502.923507
# Cat          506.683570
# Dog          965.442621
# Livestock    411.411765
# Other        459.662369

# %%
animal_outcomes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114105 entries, 0 to 114104
# Data columns (total 15 columns):
# Animal ID           114105 non-null object
# Name                78240 non-null object
# DateTime            114105 non-null datetime64[ns]
# MonthYear           114105 non-null object
# Date of Birth       114105 non-null object
# Outcome Type        114098 non-null object
# Outcome Subtype     51688 non-null object
# Animal Type         114105 non-null object
# Sex upon Outcome    114101 non-null object
# Age upon Outcome    114077 non-null object
# Breed               114105 non-null object
# Color               114105 non-null object
# age                 114077 non-null float64
# year                114105 non-null int64
# month               114105 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(11)
# memory usage: 13.1+ MB

# %%
animal_outcomes.groupby(['Animal Type', 'Sex upon Outcome']).mean().age
# Out:
# Animal Type  Sex upon Outcome
# Bird         Intact Female        803.405405
#              Intact Male          541.086093
#              Unknown              412.897106
# Cat          Intact Female        320.782064
#              Intact Male          219.976081
#              Neutered Male        676.079787
#              Spayed Female        685.390752
#              Unknown              186.176802
# Dog          Intact Female        810.742839
#              Intact Male          867.618011
#              Neutered Male       1021.148468
#              Spayed Female        985.552200
#              Unknown              368.940618
# Livestock    Intact Female        458.571429
#              Intact Male          577.000000
#              Neutered Male        365.000000
#              Unknown              133.500000
# Other        Intact Female        551.289377
#              Intact Male          497.184136
#              Neutered Male        550.568862
#              Spayed Female        545.179856
#              Unknown              446.289253
# Name: age, dtype: float64

# %% [markdown]
# #### Task 2:
# - Create new columns `year` and `month` by using a lambda function x.year on date
# - Use `groupby` and `.size()` to tell me how many animals are adopted by month

# %%
# Your code here
animal_outcomes['year'] = animal_outcomes.DateTime.apply(lambda x: x.year)
animal_outcomes['month'] = animal_outcomes.DateTime.apply(lambda x: x.month)

# %%
animal_outcomes.groupby('month').count()['Animal ID']
# Out:
# month
# 1      8209
# 2      6882
# 3      8230
# 4      8208
# 5      9999
# 6     10888
# 7     11050
# 8     10451
# 9      9701
# 10    10995
# 11     9701
# 12     9791
# Name: Animal ID, dtype: int64

# %% [markdown]
# ## 4. Reshaping a DataFrame
#
# ### `.pivot()`

# %% [markdown]
# Those of you familiar with Excel have probably used Pivot Tables. Pandas has a similar functionality.

# %%
uci.pivot(values=['sex', 'age'], columns='target')
# Out:
#         sex        age
# target    0    1     0     1
# 0       NaN  1.0   NaN  63.0
# 1       NaN  1.0   NaN  37.0
# 2       NaN  0.0   NaN  41.0
# 3       NaN  1.0   NaN  56.0
# 4       NaN  0.0   NaN  57.0
# ..      ...  ...   ...   ...
# 298     0.0  NaN  57.0   NaN
# 299     1.0  NaN  45.0   NaN
# 300     1.0  NaN  68.0   NaN
# 301     1.0  NaN  57.0   NaN
# 302     0.0  NaN  57.0   NaN
#
# [303 rows x 4 columns]

# %% [markdown]
# ### Methods for Combining DataFrames: `.join()`, `.merge()`, `.concat()`, `.melt()`

# %% [markdown]
# ### `.join()`

# %%
toy1 = pd.DataFrame([[63, 142], [33, 47]], columns=['age', 'HP'])
toy2 = pd.DataFrame([[63, 100], [33, 200]], columns=['age', 'HP'])

# %%
toy1
# Out:
#    age   HP
# 0   63  142
# 1   33   47

# %%
toy2.set_index('age').loc[63]
# Out:
# HP    100
# Name: 63, dtype: int64

# %%
toy1.join(toy2.set_index('age'),
          on='age',
          lsuffix='_A',
          rsuffix='_B').head()
# Out:
#    age  HP_A  HP_B
# 0   63   142   100
# 1   33    47   200

# %% [markdown]
# ### `.merge()`

# %%
ds_chars = pd.read_csv('data/ds_chars.csv', index_col=0)

# %%
states = pd.read_csv('data/states.csv', index_col=0)

# %%
ds_chars
# Out:
#      name   HP home_state
# 0    greg  200         WA
# 1   miles  200         WA
# 2    alan  170         TX
# 3  alison  300         DC
# 4  rachel  200         TX

# %%
states
# Out:
#   state   nickname     capital
# 0    WA  evergreen     Olympia
# 1    TX      alamo      Austin
# 2    DC   district  Washington
# 3    OH    buckeye    Columbus
# 4    OR     beaver       Salem

# %%
ds_chars.merge(states,
               left_on='home_state',
               right_on='state',
               how='right')
# Out:
#      name     HP home_state state   nickname     capital
# 0    greg  200.0         WA    WA  evergreen     Olympia
# 1   miles  200.0         WA    WA  evergreen     Olympia
# 2    alan  170.0         TX    TX      alamo      Austin
# 3  rachel  200.0         TX    TX      alamo      Austin
# 4  alison  300.0         DC    DC   district  Washington
# 5     NaN    NaN        NaN    OH    buckeye    Columbus
# 6     NaN    NaN        NaN    OR     beaver       Salem

# %% [markdown]
# ### `pd.concat()`

# %% [markdown]
# Exercise: Look up the documentation on pd.concat (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html) and use it to concatenate ds_chars and states.
# <br/>
# Your result should still have only five rows!

# %%
pd.concat([ds_chars.rename({'home_state': 'state'}), states]).reset_index()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    index     HP     capital home_state    name   nickname state
# 0      0  200.0         NaN         WA    greg        NaN   NaN
# 1      1  200.0         NaN         WA   miles        NaN   NaN
# 2      2  170.0         NaN         TX    alan        NaN   NaN
# 3      3  300.0         NaN         DC  alison        NaN   NaN
# 4      4  200.0         NaN         TX  rachel        NaN   NaN
# 5      0    NaN     Olympia        NaN     NaN  evergreen    WA
# 6      1    NaN      Austin        NaN     NaN      alamo    TX
# 7      2    NaN  Washington        NaN     NaN   district    DC
# 8      3    NaN    Columbus        NaN     NaN    buckeye    OH
# 9      4    NaN       Salem        NaN     NaN     beaver    OR

# %% [markdown]
# ### `pd.melt()`

# %% [markdown]
# Melting removes the structure from your DataFrame and puts the data in a 'variable' and 'value' format.

# %%
ds_chars.head()

# %%
pd.melt(ds_chars,
        id_vars=['name'],
        value_vars=['HP', 'home_state'])
# Out:
#      name    variable value
# 0    greg          HP   200
# 1   miles          HP   200
# 2    alan          HP   170
# 3  alison          HP   300
# 4  rachel          HP   200
# 5    greg  home_state    WA
# 6   miles  home_state    WA
# 7    alan  home_state    TX
# 8  alison  home_state    DC
# 9  rachel  home_state    TX

# %% [markdown]
# ## Bringing it all together with the Animal Shelter Data
#
# Join the data from the [Austin Animal Shelter Intake dataset](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm) to the outcomes dataset by Animal ID.
#
# Use the dates from each dataset to see how long animals spend in the shelter. Does it differ by time of year? By outcome?
#
# The Url for the Intake Dataset is here: https://data.austintexas.gov/api/views/wter-evkm/rows.csv?accessType=DOWNLOAD
#
# _Hints_ :
# - import and clean the intake dataset first
# - use apply/applymap/lambda to change the variables to their proper format in the intake data
# - rename the columns in the intake dataset *before* joining
# - create a new days-in-shelter variable
# - Notice that some values in "days_in_shelter" column are NaN or values < 0 (remove these rows using the "<" operator and ~is.na())
# - Use group_by to get some interesting information about the dataset
#
# Make sure to export and save your cleaned dataset. We will use it in a later lecture!
#
# use the notation `df.to_csv()` to write the `df` to a csv. Read more about the `to_csv()` documentation [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html)

# %%
#code here
